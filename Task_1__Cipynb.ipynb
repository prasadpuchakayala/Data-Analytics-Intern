# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

from warnings import filterwarnings
filterwarnings(action='ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Data Analytics Intern/Unemployment in India.csv")
df.head(20)
# Out:
#             Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0   Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1   Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2   Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3   Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4   Andhra Pradesh   30-09-2019    Monthly                              5.17
# 5   Andhra Pradesh   31-10-2019    Monthly                              3.52
# 6   Andhra Pradesh   30-11-2019    Monthly                              4.12
# 7   Andhra Pradesh   31-12-2019    Monthly                              4.38
# 8   Andhra Pradesh   31-01-2020    Monthly                              4.84
# 9   Andhra Pradesh   29-02-2020    Monthly                              5.91
# 10  Andhra Pradesh   31-03-2020    Monthly                              4.06
# 11  Andhra Pradesh   30-04-2020    Monthly                             16.29
# 12  Andhra Pradesh   31-05-2020    Monthly                             14.46
# 13  Andhra Pradesh   30-06-2020    Monthly                              0.85
# 14           Assam   31-05-2019    Monthly                              4.29
# 15           Assam   30-06-2019    Monthly                              5.08
# 16           Assam   31-07-2019    Monthly                              4.26
# 17           Assam   31-08-2019    Monthly                              5.79
# 18           Assam   30-09-2019    Monthly                              4.46
# 19           Assam   31-10-2019    Monthly                              4.65
#
#      Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0            11999139.0                                     43.24  Rural
# 1            11755881.0                                     42.05  Rural
# 2            12086707.0                                     43.50  Rural
# 3            12285693.0                                     43.97  Rural
# 4            12256762.0                                     44.68  Rural
# 5            12017412.0                                     43.01  Rural
# 6            11397681.0                                     41.00  Rural
# 7            12528395.0                                     45.14  Rural
# 8            12016676.0                                     43.46  Rural
# 9            11723617.0                                     42.83  Rural
# 10           11359660.0                                     40.66  Rural
# 11            8792827.0                                     36.03  Rural
# 12            9526902.0                                     38.16  Rural
# 13           15572975.0                                     53.76  Rural
# 14           11749334.0                                     57.39  Rural
# 15            8923222.0                                     43.87  Rural
# 16            9911534.0                                     48.21  Rural
# 17            9292039.0                                     45.83  Rural
# 18           11468349.0                                     55.67  Rural
# 19            8395906.0                                     40.76  Rural

# %%
df1 = pd.read_csv("/content/drive/MyDrive/Data Analytics Intern/Unemployment_Rate_upto_11_2020.csv")
df1.head(20)
# Out:
#             Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0   Andhra Pradesh   31-01-2020          M                              5.48
# 1   Andhra Pradesh   29-02-2020          M                              5.83
# 2   Andhra Pradesh   31-03-2020          M                              5.79
# 3   Andhra Pradesh   30-04-2020          M                             20.51
# 4   Andhra Pradesh   31-05-2020          M                             17.43
# 5   Andhra Pradesh   30-06-2020          M                              3.31
# 6   Andhra Pradesh   31-07-2020          M                              8.34
# 7   Andhra Pradesh   31-08-2020          M                              6.96
# 8   Andhra Pradesh   30-09-2020          M                              6.40
# 9   Andhra Pradesh   31-10-2020          M                              6.59
# 10           Assam   31-01-2020          M                              4.66
# 11           Assam   29-02-2020          M                              4.41
# 12           Assam   31-03-2020          M                              4.77
# 13           Assam   30-04-2020          M                             11.06
# 14           Assam   31-05-2020          M                              9.55
# 15           Assam   30-06-2020          M                              0.60
# 16           Assam   31-07-2020          M                              3.77
# 17           Assam   31-08-2020          M                              5.53
# 18           Assam   30-09-2020          M                              1.19
# 19           Assam   31-10-2020          M                              3.02
#
#      Estimated Employed   Estimated Labour Participation Rate (%)   Region.1  \
# 0              16635535                                     41.02      South
# 1              16545652                                     40.90      South
# 2              15881197                                     39.18      South
# 3              11336911                                     33.10      South
# 4              12988845                                     36.46      South
# 5              19805400                                     47.41      South
# 6              15431615                                     38.91      South
# 7              15251776                                     37.83      South
# 8              15220312                                     37.47      South
# 9              15157557                                     37.34      South
# 10             13051904                                     52.98  Northeast
# 11             10088268                                     40.77  Northeast
# 12             11542888                                     46.73  Northeast
# 13              6830817                                     29.55  Northeast
# 14             11367897                                     48.26  Northeast
# 15              9095944                                     35.07  Northeast
# 16             10286757                                     40.88  Northeast
# 17              9781310                                     39.52  Northeast
# 18             14107641                                     54.38  Northeast
# 19             11949329                                     46.84  Northeast
#
#     longitude  latitude
# 0     15.9129   79.7400
# 1     15.9129   79.7400
# 2     15.9129   79.7400
# 3     15.9129   79.7400
# 4     15.9129   79.7400
# 5     15.9129   79.7400
# 6     15.9129   79.7400
# 7     15.9129   79.7400
# 8     15.9129   79.7400
# 9     15.9129   79.7400
# 10    26.2006   92.9376
# 11    26.2006   92.9376
# 12    26.2006   92.9376
# 13    26.2006   92.9376
# 14    26.2006   92.9376
# 15    26.2006   92.9376
# 16    26.2006   92.9376
# 17    26.2006   92.9376
# 18    26.2006   92.9376
# 19    26.2006   92.9376

# %% [markdown]
# We can observe from the two datasets that while they both appear identical, they each provide different information. Data in the First Dataset spans from 2019 to the first part of 2020. Additionally, only data from the first to the tenth month of 2020 is provided in the second dataset. Additionally, while the columns and factors in the two datasets are the same, the results are not. I therefore choose to examine both datasets.

# %% [markdown]
# ## Unemployment in India(2019-2020)

# %%
df.duplicated().sum()
# Out:
# 27

# %%
df = df.drop_duplicates()

# %%
df = df.reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# Region                                      1
#  Date                                       1
#  Frequency                                  1
#  Estimated Unemployment Rate (%)            1
#  Estimated Employed                         1
#  Estimated Labour Participation Rate (%)    1
# Area                                        1
# dtype: int64

# %%
df = df.dropna()
df = df.reset_index(drop=True)

# %%
# Remove leading and trailing whitespaces from column names
df.columns = df.columns.str.strip()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Region                                   740 non-null    object
#  1   Date                                     740 non-null    object
#  2   Frequency                                740 non-null    object
#  3   Estimated Unemployment Rate (%)          740 non-null    float64
#  4   Estimated Employed                       740 non-null    float64
#  5   Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                     740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 40.6+ KB

# %%
df.describe().T
# Out:
#                                          count          mean           std  \
# Estimated Unemployment Rate (%)          740.0  1.178795e+01  1.072130e+01
# Estimated Employed                       740.0  7.204460e+06  8.087988e+06
# Estimated Labour Participation Rate (%)  740.0  4.263012e+01  8.111094e+00
#
#                                               min           25%         50%  \
# Estimated Unemployment Rate (%)              0.00  4.657500e+00        8.35
# Estimated Employed                       49420.00  1.190404e+06  4744178.50
# Estimated Labour Participation Rate (%)     13.33  3.806250e+01       41.16
#
#                                                   75%          max
# Estimated Unemployment Rate (%)          1.588750e+01        76.74
# Estimated Employed                       1.127549e+07  45777509.00
# Estimated Labour Participation Rate (%)  4.550500e+01        72.57

# %%
df.rename(columns={'Region': 'State'}, inplace=True)

# %% [markdown]
# ## Average, Highest and Lowest Unemployment Rate

# %%
# Calculate the average unemployment rate by state
average_unemployment_rate = df.groupby('State')['Estimated Unemployment Rate (%)'].mean()

# Find the state with the highest unemployment rate
state_with_highest_unemployment = average_unemployment_rate.idxmax()
highest_unemployment_rate = average_unemployment_rate.max()

# Find the state with the lowest unemployment rate
state_with_lowest_unemployment = average_unemployment_rate.idxmin()
lowest_unemployment_rate = average_unemployment_rate.min()


print("State with the highest unemployment rate:", state_with_highest_unemployment)
print("Highest unemployment rate:", highest_unemployment_rate)
print("State with the lowest unemployment rate:", state_with_lowest_unemployment)
print("Lowest unemployment rate:", lowest_unemployment_rate)


sns.set_palette("husl")

plt.figure(figsize=(12, 6))
average_unemployment_rate.sort_values(ascending=False).plot(kind='bar')
plt.title("Average Unemployment Rate by State")
plt.xlabel("State")
plt.ylabel("Average Unemployment Rate (%)")
plt.xticks(rotation=90)
plt.show()
# Out:
# State with the highest unemployment rate: Tripura
# Highest unemployment rate: 28.350357142857142
# State with the lowest unemployment rate: Meghalaya
# Lowest unemployment rate: 4.7988888888888885

# %% [markdown]
# ## Box Plot of Unemployment Rate Distribution by State

# %%
sns.set_palette("husl")

plt.figure(figsize=(12, 6))
sns.boxplot(x='State', y='Estimated Unemployment Rate (%)', data=df)
plt.title("Unemployment Rate Distribution by State")
plt.xlabel("State")
plt.ylabel("Estimated Unemployment Rate (%)")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Histogram of Unemployment Rate Distribution

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Estimated Unemployment Rate (%)'], bins=20, edgecolor='k')
plt.title("Unemployment Rate Distribution")
plt.xlabel("Estimated Unemployment Rate (%)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Line Plot of Unemployment Rate Over Time by State

# %%
sns.set_palette("tab20")

plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='Estimated Unemployment Rate (%)', hue='State', data=df)
plt.title("Unemployment Rate Over Time by State")
plt.xlabel("Date")
plt.ylabel("Estimated Unemployment Rate (%)")
plt.xticks(rotation=45)
plt.legend(title='State', loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# ## Pair Plot for Exploring Relationships Between Numerical Columns

# %%
sns.set_palette("husl")

sns.pairplot(df[['Estimated Unemployment Rate (%)', 'Estimated Employed', 'Estimated Labour Participation Rate (%)']], diag_kind='kde')
plt.suptitle("Pair Plot of Numerical Columns", y=1.02)
plt.show()

# %% [markdown]
# ## Unemployment Rate vs. Labor Participation Rate

# %%
sns.set_palette("Set2")

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Estimated Unemployment Rate (%)', y='Estimated Labour Participation Rate (%)', data=df, hue='State', palette='Set2', legend='full')
plt.title('Unemployment Rate vs. Labor Participation Rate')
plt.xlabel('Estimated Unemployment Rate (%)')
plt.ylabel('Estimated Labour Participation Rate (%)')
plt.legend(title='State', loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.grid(True)
plt.show()

# %%
correlation_matrix = df[['Estimated Unemployment Rate (%)', 'Estimated Employed', 'Estimated Labour Participation Rate (%)']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
colors = sns.color_palette("Set2", n_colors=len(df['State'].unique()))

# Grouping the data by 'Frequency' and 'State' and calculate the mean of 'Estimated Unemployment Rate (%)'
grouped_data = df.groupby(['Frequency', 'State'])['Estimated Unemployment Rate (%)'].mean().unstack()

plt.figure(figsize=(12, 6))
grouped_data.plot(kind='bar', stacked=True, color=colors)
plt.xlabel('Frequency(2019 and 2020)')
plt.ylabel('Estimated Unemployment Rate (%)')
plt.title('Unemployment Rate by Frequency and State')
plt.legend(title='State', loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.grid(True)
plt.show()

# %% [markdown]
# ## Analysis on whole Country

# %%
df['Date'] = pd.to_datetime(df['Date'].str.strip(), format='%d-%m-%Y')

# %%
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#                      State Frequency  Estimated Unemployment Rate (%)  \
# Date
# 2019-05-31  Andhra Pradesh   Monthly                             3.65
# 2019-06-30  Andhra Pradesh   Monthly                             3.05
# 2019-07-31  Andhra Pradesh   Monthly                             3.75
# 2019-08-31  Andhra Pradesh   Monthly                             3.32
# 2019-09-30  Andhra Pradesh   Monthly                             5.17
#
#             Estimated Employed  Estimated Labour Participation Rate (%)   Area
# Date
# 2019-05-31          11999139.0                                    43.24  Rural
# 2019-06-30          11755881.0                                    42.05  Rural
# 2019-07-31          12086707.0                                    43.50  Rural
# 2019-08-31          12285693.0                                    43.97  Rural
# 2019-09-30          12256762.0                                    44.68  Rural

# %%
# Drop the 'State' column
df_numeric = df.drop(columns=['State','Frequency','Area'])

# Group by date and calculate the mean of all numeric columns
df_numeric_avg = df_numeric.groupby('Date').mean()

# %%
df_numeric_avg
# Out:
#             Estimated Unemployment Rate (%)  Estimated Employed  \
# Date
# 2019-05-31                         8.874259        7.410148e+06
# 2019-06-30                         9.303333        7.358642e+06
# 2019-07-31                         9.033889        7.404425e+06
# 2019-08-31                         9.637925        7.539815e+06
# 2019-09-30                         9.051731        7.739464e+06
# 2019-10-31                         9.900909        7.298382e+06
# 2019-11-30                         9.868364        7.273661e+06
# 2019-12-31                         9.497358        7.377388e+06
# 2020-01-31                         9.950755        7.677344e+06
# 2020-02-29                         9.964717        7.603996e+06
# 2020-03-31                        10.700577        7.516581e+06
# 2020-04-30                        23.641569        5.283320e+06
# 2020-05-31                        24.875294        5.879363e+06
# 2020-06-30                        11.903600        7.387009e+06
#
#             Estimated Labour Participation Rate (%)
# Date
# 2019-05-31                                43.902963
# 2019-06-30                                43.750556
# 2019-07-31                                43.706667
# 2019-08-31                                43.646792
# 2019-09-30                                44.301346
# 2019-10-31                                44.001273
# 2019-11-30                                44.110545
# 2019-12-31                                43.667358
# 2020-01-31                                44.051321
# 2020-02-29                                43.723019
# 2020-03-31                                43.084038
# 2020-04-30                                35.141176
# 2020-05-31                                38.496863
# 2020-06-30                                40.548400

# %%
# Plot Estimated Unemployment Rate over time
plt.figure(figsize=(12, 6))
plt.plot(df_numeric_avg.index, df_numeric_avg['Estimated Unemployment Rate (%)'], marker='o', linestyle='-')
plt.title('Estimated Unemployment Rate Over Time')
plt.xlabel('Date')
plt.ylabel('Unemployment Rate (%)')
plt.grid(True)
plt.show()

# %%
# Histogram of Estimated Unemployment Rate
plt.figure(figsize=(10, 6))
plt.hist(df_numeric_avg['Estimated Unemployment Rate (%)'], bins=20, density=True, alpha=0.7, color='blue')
plt.title('Histogram of Estimated Unemployment Rate')
plt.xlabel('Unemployment Rate (%)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Density Plot of Estimated Unemployment Rate
plt.figure(figsize=(10, 6))
df_numeric_avg['Estimated Unemployment Rate (%)'].plot(kind='kde', color='blue')
plt.title('Density Plot of Estimated Unemployment Rate')
plt.xlabel('Unemployment Rate (%)')
plt.grid(True)
plt.show()

# %% [markdown]
# As a result of the analysis above, we can see India's unemployment rate for the years 2019–2020. We can observe from the various visualisations how much unemployment increased when COVID 19 arrived.

# %% [markdown]
# ## Unemployment in India (2020-)

# %%
df1.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# 1    15.9129     79.74
# 2    15.9129     79.74
# 3    15.9129     79.74
# 4    15.9129     79.74

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
# Remove leading and trailing whitespaces from column names
df1.columns = df1.columns.str.strip()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Region                                   267 non-null    object
#  1   Date                                     267 non-null    object
#  2   Frequency                                267 non-null    object
#  3   Estimated Unemployment Rate (%)          267 non-null    float64
#  4   Estimated Employed                       267 non-null    int64
#  5   Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                 267 non-null    object
#  7   longitude                                267 non-null    float64
#  8   latitude                                 267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
df1.describe().T
# Out:
#                                          count          mean           std  \
# Estimated Unemployment Rate (%)          267.0  1.223693e+01  1.080328e+01
# Estimated Employed                       267.0  1.396211e+07  1.336632e+07
# Estimated Labour Participation Rate (%)  267.0  4.168157e+01  7.845419e+00
# longitude                                267.0  2.282605e+01  6.270731e+00
# latitude                                 267.0  8.053242e+01  5.831738e+00
#
#                                                  min           25%  \
# Estimated Unemployment Rate (%)               0.5000  4.845000e+00
# Estimated Employed                       117542.0000  2.838930e+06
# Estimated Labour Participation Rate (%)      16.7700  3.726500e+01
# longitude                                    10.8505  1.811240e+01
# latitude                                     71.1924  7.608560e+01
#
#                                                   50%           75%  \
# Estimated Unemployment Rate (%)          9.650000e+00  1.675500e+01
# Estimated Employed                       9.732417e+06  2.187869e+07
# Estimated Labour Participation Rate (%)  4.039000e+01  4.405500e+01
# longitude                                2.361020e+01  2.727840e+01
# latitude                                 7.901930e+01  8.527990e+01
#
#                                                   max
# Estimated Unemployment Rate (%)          7.585000e+01
# Estimated Employed                       5.943376e+07
# Estimated Labour Participation Rate (%)  6.969000e+01
# longitude                                3.377820e+01
# latitude                                 9.293760e+01

# %% [markdown]
# ## Analyzing Data By barplots

# %%
import plotly.express as px

fg1 = px.bar(df1, x='Region', y='Estimated Unemployment Rate (%)', color='Region',
             title='Unemployment rate in 2020-', animation_frame='Date', template='plotly')
fg1.update_layout(xaxis={'categoryorder': 'total descending'})
fg1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8c5f8cc5-6577-4d8e-989a-33d544d878b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c5f8cc5-6577-4d8e-989a-33d544d878b5")) {                    Plotly.newPlot(                        "8c5f8cc5-6577-4d8e-989a-33d544d878b5",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Andhra Pradesh"],"xaxis":"x","y":[5.48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Assam","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Assam","offsetgroup":"Assam","orientation":"v","showlegend":true,"textposition":"auto","x":["Assam"],"xaxis":"x","y":[4.66],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bihar","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bihar","offsetgroup":"Bihar","orientation":"v","showlegend":true,"textposition":"auto","x":["Bihar"],"xaxis":"x","y":[10.61],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chhattisgarh","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Chhattisgarh","offsetgroup":"Chhattisgarh","orientation":"v","showlegend":true,"textposition":"auto","x":["Chhattisgarh"],"xaxis":"x","y":[9.65],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"textposition":"auto","x":["Delhi"],"xaxis":"x","y":[22.23],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Goa","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Goa","offsetgroup":"Goa","orientation":"v","showlegend":true,"textposition":"auto","x":["Goa"],"xaxis":"x","y":[8.89],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gujarat","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Gujarat","offsetgroup":"Gujarat","orientation":"v","showlegend":true,"textposition":"auto","x":["Gujarat"],"xaxis":"x","y":[5.54],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Haryana","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Haryana","offsetgroup":"Haryana","orientation":"v","showlegend":true,"textposition":"auto","x":["Haryana"],"xaxis":"x","y":[20.34],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eEstimate ...

# %%
fg1 = px.bar(df1, x='Region.1', y='Estimated Unemployment Rate (%)', color='Region',
             title='Unemployment rate in 2020-', animation_frame='Date', template='plotly')
fg1.update_layout(xaxis={'categoryorder': 'total descending'})
fg1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d1603314-a9ff-44e7-81b7-cbcdfec657c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1603314-a9ff-44e7-81b7-cbcdfec657c4")) {                    Plotly.newPlot(                        "d1603314-a9ff-44e7-81b7-cbcdfec657c4",                        [{"alignmentgroup":"True","hovertemplate":"Region=Andhra Pradesh\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["South"],"xaxis":"x","y":[5.48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=Assam\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Assam","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Assam","offsetgroup":"Assam","orientation":"v","showlegend":true,"textposition":"auto","x":["Northeast"],"xaxis":"x","y":[4.66],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=Bihar\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bihar","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bihar","offsetgroup":"Bihar","orientation":"v","showlegend":true,"textposition":"auto","x":["East"],"xaxis":"x","y":[10.61],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=Chhattisgarh\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chhattisgarh","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Chhattisgarh","offsetgroup":"Chhattisgarh","orientation":"v","showlegend":true,"textposition":"auto","x":["West"],"xaxis":"x","y":[9.65],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=Delhi\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"textposition":"auto","x":["North"],"xaxis":"x","y":[22.23],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=Goa\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Goa","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Goa","offsetgroup":"Goa","orientation":"v","showlegend":true,"textposition":"auto","x":["West"],"xaxis":"x","y":[8.89],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=Gujarat\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gujarat","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Gujarat","offsetgroup":"Gujarat","orientation":"v","showlegend":true,"textposition":"auto","x":["West"],"xaxis":"x","y":[5.54],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=Haryana\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Haryana","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Haryana","offsetgroup":"Haryana","or ...

# %% [markdown]
# ## Time Series Line Plot for Unemployment Rate by Region

# %%
line_plot = px.line(df1, x='Date', y='Estimated Unemployment Rate (%)', color='Region',
                    title='Unemployment Rate Over Time', template='plotly')
line_plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="27f7ca6e-f6e8-4980-aa09-9ecca13d0849" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27f7ca6e-f6e8-4980-aa09-9ecca13d0849")) {                    Plotly.newPlot(                        "27f7ca6e-f6e8-4980-aa09-9ecca13d0849",                        [{"hovertemplate":"Region=Andhra Pradesh\u003cbr\u003eDate=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andhra Pradesh","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Andhra Pradesh","orientation":"v","showlegend":true,"x":[" 31-01-2020"," 29-02-2020"," 31-03-2020"," 30-04-2020"," 31-05-2020"," 30-06-2020"," 31-07-2020"," 31-08-2020"," 30-09-2020"," 31-10-2020"],"xaxis":"x","y":[5.48,5.83,5.79,20.51,17.43,3.31,8.34,6.96,6.4,6.59],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Assam\u003cbr\u003eDate=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Assam","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Assam","orientation":"v","showlegend":true,"x":[" 31-01-2020"," 29-02-2020"," 31-03-2020"," 30-04-2020"," 31-05-2020"," 30-06-2020"," 31-07-2020"," 31-08-2020"," 30-09-2020"," 31-10-2020"],"xaxis":"x","y":[4.66,4.41,4.77,11.06,9.55,0.6,3.77,5.53,1.19,3.02],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Bihar\u003cbr\u003eDate=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bihar","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bihar","orientation":"v","showlegend":true,"x":[" 31-01-2020"," 29-02-2020"," 31-03-2020"," 30-04-2020"," 31-05-2020"," 30-06-2020"," 31-07-2020"," 31-08-2020"," 30-09-2020"," 31-10-2020"],"xaxis":"x","y":[10.61,10.29,15.43,46.64,45.96,17.82,12.79,13.44,11.91,9.82],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Chhattisgarh\u003cbr\u003eDate=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chhattisgarh","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Chhattisgarh","orientation":"v","showlegend":true,"x":[" 31-01-2020"," 29-02-2020"," 31-03-2020"," 30-04-2020"," 31-05-2020"," 30-06-2020"," 31-07-2020"," 31-08-2020"," 30-09-2020"," 31-10-2020"],"xaxis":"x","y":[9.65,8.38,7.54,3.41,10.5,14.23,10.27,5.63,1.96,6.62],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Delhi\u003cbr\u003eDate=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Delhi","orientation":"v","showlegend":true,"x":[" 31-01-2020"," 29-02-2020"," 31-03-2020"," 30-04-2020"," 31-05-2020"," 30-06-2020"," 31-07-2020"," 31-08-2020"," 30-09-2020"," 31-10-2020"],"xaxis":"x","y":[22.23,14.84,17.04,16.68,42.27,18.19,20.3,13.79,12.53,6.27],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Goa\u003cbr\u003eDate=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Goa","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Goa","orientation":"v","showlegend":true,"x":[" 31-01-2020"," 29-02-2020"," 31-03-2020"," 30-04-2020"," 31-05-2020"," 30-06-2020"," 31-07-2020"," 31-08-2020"," 30-09-2020"," 31-10-2020"],"xaxis":"x","y":[8.89,2.81,5.25,13.31,21.25,9.96,17.07,16.21,15.38,11.54],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Gujarat\u003cbr\u003eDate=%{x}\u003cbr\u003eEstimated U ...

# %% [markdown]
# ## Bar Plot for Average Unemployment Rate by Region

# %%
avg_unemployment = df1.groupby('Region')['Estimated Unemployment Rate (%)'].mean().reset_index()

bar_plot = px.bar(avg_unemployment, x='Region', y='Estimated Unemployment Rate (%)',
                   title='Average Unemployment Rate by Region', template='plotly')
bar_plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cd32c72e-6a53-4421-a697-15dd916ea4f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd32c72e-6a53-4421-a697-15dd916ea4f2")) {                    Plotly.newPlot(                        "cd32c72e-6a53-4421-a697-15dd916ea4f2",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Andhra Pradesh","Assam","Bihar","Chhattisgarh","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu & Kashmir","Jharkhand","Karnataka","Kerala","Madhya Pradesh","Maharashtra","Meghalaya","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telangana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"xaxis":"x","y":[8.664,4.856,19.471,7.819,18.414,12.167,6.3759999999999994,27.476999999999997,16.065,16.477777777777778,19.538999999999998,7.667999999999999,9.434000000000001,6.854000000000001,7.979000000000001,3.8659999999999997,6.462000000000001,17.942,11.981,15.868,9.7925,12.187,6.833,25.055,9.737,11.156,10.192],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type" ...

# %% [markdown]
# ## Scatter Plot for Unemployment Rate vs. Estimated Employed

# %%
scatter_plot = px.scatter(df1, x='Estimated Employed', y='Estimated Unemployment Rate (%)',
                          color='Region', title='Unemployment Rate vs. Estimated Employed', template='plotly')
scatter_plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2015b85e-f6a5-4ee5-8fd0-710c8b3dcf0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2015b85e-f6a5-4ee5-8fd0-710c8b3dcf0a")) {                    Plotly.newPlot(                        "2015b85e-f6a5-4ee5-8fd0-710c8b3dcf0a",                        [{"hovertemplate":"Region=Andhra Pradesh\u003cbr\u003eEstimated Employed=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Andhra Pradesh","orientation":"v","showlegend":true,"x":[16635535,16545652,15881197,11336911,12988845,19805400,15431615,15251776,15220312,15157557],"xaxis":"x","y":[5.48,5.83,5.79,20.51,17.43,3.31,8.34,6.96,6.4,6.59],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Assam\u003cbr\u003eEstimated Employed=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Assam","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Assam","orientation":"v","showlegend":true,"x":[13051904,10088268,11542888,6830817,11367897,9095944,10286757,9781310,14107641,11949329],"xaxis":"x","y":[4.66,4.41,4.77,11.06,9.55,0.6,3.77,5.53,1.19,3.02],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Bihar\u003cbr\u003eEstimated Employed=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bihar","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Bihar","orientation":"v","showlegend":true,"x":[26397671,26281655,25717519,16046236,16280203,23963933,24989370,23795534,26902907,25693252],"xaxis":"x","y":[10.61,10.29,15.43,46.64,45.96,17.82,12.79,13.44,11.91,9.82],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Chhattisgarh\u003cbr\u003eEstimated Employed=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chhattisgarh","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Chhattisgarh","orientation":"v","showlegend":true,"x":[8552172,9195114,9302317,7600448,6991217,7332807,8620294,9050422,9021854,8546847],"xaxis":"x","y":[9.65,8.38,7.54,3.41,10.5,14.23,10.27,5.63,1.96,6.62],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Delhi\u003cbr\u003eEstimated Employed=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Delhi","orientation":"v","showlegend":true,"x":[5805284,5856307,5553805,3119274,2632404,4418914,4291053,4850107,4958373,4842698],"xaxis":"x","y":[22.23,14.84,17.04,16.68,42.27,18.19,20.3,13.79,12.53,6.27],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Goa\u003cbr\u003eEstimated Employed=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Goa","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Goa","orientation":"v","showlegend":true,"x":[416750,478068,411761,500614,378244,489111,458876,473016,425004,392304],"xaxis":"x","y":[8.89,2.81,5.25,13.31,21.25,9.96,17.07,16.21,15.38,11.54],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Gujarat\u003cbr\u003eEstimated Employed=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gujarat","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Gujarat","orientation":"v","showlegend":true,"x":[24126346,24757795,23566641,15288878,17836936,23657055,24276120,22817232,25010199,25970259],"xaxis":"x","y":[5.54,6.38,6.66,18.71,12.11,3.2,1.84,1.87,3.42,4.03],"yax ...

# %%
scatter_plot = px.scatter(df1, x='Region.1', y='Estimated Unemployment Rate (%)', color='Region',
                          title='Unemployment Rate by Region.1 Over Time', animation_frame='Date', template='plotly')

scatter_plot.update_xaxes(categoryorder='total descending')

scatter_plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a76f1fc1-6b3e-424a-8b26-055c0552efa4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a76f1fc1-6b3e-424a-8b26-055c0552efa4")) {                    Plotly.newPlot(                        "a76f1fc1-6b3e-424a-8b26-055c0552efa4",                        [{"hovertemplate":"Region=Andhra Pradesh\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Andhra Pradesh","orientation":"v","showlegend":true,"x":["South"],"xaxis":"x","y":[5.48],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Assam\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Assam","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Assam","orientation":"v","showlegend":true,"x":["Northeast"],"xaxis":"x","y":[4.66],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Bihar\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bihar","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Bihar","orientation":"v","showlegend":true,"x":["East"],"xaxis":"x","y":[10.61],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Chhattisgarh\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chhattisgarh","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Chhattisgarh","orientation":"v","showlegend":true,"x":["West"],"xaxis":"x","y":[9.65],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Delhi\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Delhi","orientation":"v","showlegend":true,"x":["North"],"xaxis":"x","y":[22.23],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Goa\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Goa","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Goa","orientation":"v","showlegend":true,"x":["West"],"xaxis":"x","y":[8.89],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Gujarat\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gujarat","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Gujarat","orientation":"v","showlegend":true,"x":["West"],"xaxis":"x","y":[5.54],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Haryana\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Haryana","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Haryana","orientation":"v","showlegend":true,"x":["North"],"xaxis":"x","y":[20.34],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Himachal Pradesh\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003eEstimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Himachal Pradesh","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"Himachal Pradesh","o ...

# %% [markdown]
# ## Histogram for Estimated Labour Participation Rate

# %%
histogram = px.histogram(df1, x='Estimated Labour Participation Rate (%)', color='Region',
                         title='Distribution of Labour Participation Rate by Region', template='plotly')
histogram.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="535abc35-9a2e-4af9-932b-a3a24e51c976" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("535abc35-9a2e-4af9-932b-a3a24e51c976")) {                    Plotly.newPlot(                        "535abc35-9a2e-4af9-932b-a3a24e51c976",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Andhra Pradesh\u003cbr\u003eEstimated Labour Participation Rate (%)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"x":[41.02,40.9,39.18,33.1,36.46,47.41,38.91,37.83,37.47,37.34],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Assam\u003cbr\u003eEstimated Labour Participation Rate (%)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Assam","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Assam","offsetgroup":"Assam","orientation":"v","showlegend":true,"x":[52.98,40.77,46.73,29.55,48.26,35.07,40.88,39.52,54.38,46.84],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Bihar\u003cbr\u003eEstimated Labour Participation Rate (%)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bihar","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bihar","offsetgroup":"Bihar","orientation":"v","showlegend":true,"x":[37.72,37.35,38.69,38.17,38.16,36.86,36.14,34.59,38.35,35.7],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Chhattisgarh\u003cbr\u003eEstimated Labour Participation Rate (%)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chhattisgarh","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Chhattisgarh","offsetgroup":"Chhattisgarh","orientation":"v","showlegend":true,"x":[43.08,45.58,45.59,35.58,35.23,38.48,43.14,42.97,41.14,40.82],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Delhi\u003cbr\u003eEstimated Labour Participation Rate (%)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"x":[47.79,43.92,42.65,23.8,28.91,34.17,33.97,35.41,35.59,32.36],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Goa\u003cbr\u003eEstimated Labour Participation Rate (%)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Goa","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Goa","offsetgroup":"Goa","orientation":"v","showlegend":true,"x":[35.73,38.38,33.88,44.97,37.36,42.21,42.94,43.76,38.89,34.3],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Gujarat\u003cbr\u003eEstimated Labour Participation Rate (%)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gujarat","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Gujarat","offsetgroup":"Gujarat","orientation":"v","showlegend":true,"x":[48.49,50.11,47.75,35.5,38.23,45.96,46.41,43.55,48.41,50.49],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Haryana\u003cbr\u003eEstimated Labour Participation Rate (%)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Haryana","marker": ...

# %%
histogram = px.histogram(df1, x='Region.1', y='Estimated Unemployment Rate (%)', color='Region',
                         title='Unemployment Rate Distribution by Region.1 Over Time', animation_frame='Date', template='plotly')

histogram.update_xaxes(categoryorder='total descending')

histogram.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="637f7c9f-abb3-49e4-9ca7-14fd6a1d3008" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("637f7c9f-abb3-49e4-9ca7-14fd6a1d3008")) {                    Plotly.newPlot(                        "637f7c9f-abb3-49e4-9ca7-14fd6a1d3008",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Region=Andhra Pradesh\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003esum of Estimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"x":["South"],"xaxis":"x","y":[5.48],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Region=Assam\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003esum of Estimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Assam","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Assam","offsetgroup":"Assam","orientation":"v","showlegend":true,"x":["Northeast"],"xaxis":"x","y":[4.66],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Region=Bihar\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003esum of Estimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bihar","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bihar","offsetgroup":"Bihar","orientation":"v","showlegend":true,"x":["East"],"xaxis":"x","y":[10.61],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Region=Chhattisgarh\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003esum of Estimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chhattisgarh","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Chhattisgarh","offsetgroup":"Chhattisgarh","orientation":"v","showlegend":true,"x":["West"],"xaxis":"x","y":[9.65],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Region=Delhi\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003esum of Estimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"x":["North"],"xaxis":"x","y":[22.23],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Region=Goa\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003esum of Estimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Goa","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Goa","offsetgroup":"Goa","orientation":"v","showlegend":true,"x":["West"],"xaxis":"x","y":[8.89],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Region=Gujarat\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003esum of Estimated Unemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gujarat","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Gujarat","offsetgroup":"Gujarat","orientation":"v","showlegend":true,"x":["West"],"xaxis":"x","y":[5.54],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Region=Haryana\u003cbr\u003eDate= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003esum o ...
